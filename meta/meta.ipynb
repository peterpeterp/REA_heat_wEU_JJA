# %%
import os,sys,subprocess,glob,cftime,importlib,pickle
from datetime import datetime
import xarray as xr
import numpy as np
import pandas as pd

def import_from(module, name):
    module = __import__(module, fromlist=[name])
    return getattr(module, name)

import warnings
warnings.filterwarnings("ignore")

sys.path.append('../')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from experiment_configuration.experiment import experiment
experiments = {}
for experiment_identifier in [f"c{i}" for i in range(1,6)] + [f"p{i}" for i in range(1,6)]:
    experiments[experiment_identifier] = experiment(import_from(f'experiment_configuration.{experiment_identifier}', 'config'))

# %%
all_variables = []
for name,exp in experiments.items():
    print('-'*20)
    print(name)
    run_dir = f"{exp.dir_archive}/GKLT/{exp.experiment_name}/{name}_000"
    file_dict = {}
    for fl in sorted(glob.glob(f"{run_dir}/*/*/*.nc")):

        if 'post' not in fl:
            realm = fl.split('/hist')[0].split('/')[-1]
            h_identifier = fl.split('.')[-3] 
            l = []
            nc = xr.open_dataset(fl)
            for var,e in nc.items():
                if e.dims == ('time', 'lat', 'lon'):
                    if e.time.shape[0] == 5:
                        l.append(var)
                        all_variables.append(var)

            if len(l) > 0:
                print(realm, h_identifier, l)
                file_dict[f"{realm} {h_identifier}"] = l
            #print(fl)
    print(file_dict)
# Out:
# --------------------
# c1
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'Z500']
# lnd h7 ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'Z500'], 'lnd h7': ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']}
# --------------------
# p1
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'Z500']
# lnd h7 ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'Z500'], 'lnd h7': ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']}
# --------------------
# c2
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']}
# --------------------
# p2
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['FIRE', 'GPP', 'HR', 'NBP', 'TLAI', 'TOTFIRE', 'TOTLITC', 'TOTVEGC', 'TWS']}
# --------------------
# c3
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']}
# --------------------
# p3
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']}
# --------------------
# c4
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']}
# --------------------
# p4
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']}
# --------------------
# c5
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']}
# --------------------
# p5
# atm h1 ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500']
# atm h2 ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX']
# lnd h7 ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']
# {'atm h1': ['ICEFRAC', 'PRECC', 'PRECL', 'PS', 'PSL', 'QREFHT', 'RHREFHT', 'SST', 'TREFHT', 'TREFHTMN', 'TREFHTMX', 'U200', 'U500', 'V200', 'V500', 'Z200', 'Z500'], 'atm h2': ['FLDS', 'FLNS', 'FSDS', 'FSNS', 'LHFLX', 'SHFLX'], 'lnd h7': ['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FSH', 'FSNO', 'GPP', 'NBP', 'PBOT', 'QFLX_EVAP_TOT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'SOILWATER_10CM', 'TLAI', 'TOTSOILLIQ', 'TSOI_10CM', 'U10']}

# %%
np.unique(all_variables)
# Out:
# array(['EFLX_GNET', 'EFLX_LH_TOT', 'FAREA_BURNED', 'FIRE', 'FLDS', 'FLNS',
#        'FSDS', 'FSH', 'FSNO', 'FSNS', 'GPP', 'HR', 'ICEFRAC', 'LHFLX',
#        'NBP', 'PBOT', 'PRECC', 'PRECL', 'PS', 'PSL', 'QFLX_EVAP_TOT',
#        'QREFHT', 'QRUNOFF', 'QVEGT', 'RH2M', 'RH2M_U', 'RHREFHT', 'SHFLX',
#        'SOILWATER_10CM', 'SST', 'TLAI', 'TOTFIRE', 'TOTLITC',
#        'TOTSOILLIQ', 'TOTVEGC', 'TREFHT', 'TREFHTMN', 'TREFHTMX',
#        'TSOI_10CM', 'TWS', 'U10', 'U200', 'U500', 'V200', 'V500', 'Z200',
#        'Z500'], dtype='<U14')

# %%
available = pd.DataFrame(columns=list(experiments.keys()))
for var in np.unique(all_variables):
    available.loc[var,:] = ''
    for name,exp in experiments.items():
        run_dir = f"{exp.dir_archive}/GKLT/{exp.experiment_name}/{name}_000"
        file_dict = {}
        for fl in sorted(glob.glob(f"{run_dir}/*/*/*.nc")):

            if 'post' not in fl:
                realm = fl.split('/hist')[0].split('/')[-1]
                h_identifier = fl.split('.')[-3] 
                nc = xr.open_dataset(fl)
                for vv,e in nc.items():
                    if vv == var:
                        if e.dims == ('time', 'lat', 'lon'):
                            if e.time.shape[0] == 5:
                                available.loc[var, name] = 'x'

# %%
available.columns = [f"{exp.initial_conditions_name}-x{exp.experiment_identifier[1]}" for exp in experiments.values()]

# %%
available
# Out:
#                ssp370-2025-x1 ssp370-2025-x2 ssp370-2025-x3 ssp370-2025-x4  \
# EFLX_GNET                                                 x              x
# EFLX_LH_TOT                                               x              x
# FAREA_BURNED                                              x              x
# FIRE                        x              x
# FLDS                                       x              x              x
# FLNS                                       x              x              x
# FSDS                                       x              x              x
# FSH                                                       x              x
# FSNO                                                      x              x
# FSNS                                       x              x              x
# GPP                         x              x              x              x
# HR                          x              x
# ICEFRAC                     x              x              x              x
# LHFLX                                      x              x              x
# NBP                         x              x              x              x
# PBOT                                                      x              x
# PRECC                       x              x              x              x
# PRECL                       x              x              x              x
# PS                          x              x              x              x
# PSL                         x              x              x              x
# QFLX_EVAP_TOT                                             x              x
# QREFHT                      x              x              x              x
# QRUNOFF                                                   x              x
# QVEGT                                                     x              x
# RH2M                                                      x              x
# RH2M_U                                                    x              x
# RHREFHT                     x              x              x              x
# SHFLX                                      x              x              x
# SOILWATER_10CM                                            x              x
# SST                         x              x              x              x
# TLAI                        x              x              x              x
# TOTFIRE                     x              x
# TOTLITC                     x              x
# TOTSOILLIQ                                                x              x
# TOTVEGC                     x              x
# TREFHT                      x              x              x              x
# TREFHTMN                    x              x              x              x
# TREFHTMX                    x              x              x              x
# TSOI_10CM                                                 x              x
# TWS                         x              x
# U10                                                       x              x
# U200                                       x              x              x
# U500                                       x              x              x
# V200                                       x              x              x
# V500                                       x              x              x
# Z200                                       x              x              x
# Z500                        x              x              x              x
#
#                ssp370-2025-x5 piControl-x1 piControl-x2 piControl-x3  \
# EFLX_GNET                   x                                      x
# EFLX_LH_TOT                 x                                      x
# FAREA_BURNED                x                                      x
# FIRE                                     x            x
# FLDS                        x                         x            x
# FLNS                        x                         x            x
# FSDS                        x                         x            x
# FSH                         x                                      x
# FSNO                        x                                      x
# FSNS                        x                         x            x
# GPP                         x            x            x            x
# HR                                       x            x
# ICEFRAC                     x            x            x            x
# LHFLX                       x                         x            x
# NBP                         x            x            x            x
# PBOT                        x                                      x
# PRECC                       x            x            x            x
# PRECL                       x            x            x            x
# PS                          x            x            x            x
# PSL                         x            x            x            x
# QFLX_EVAP_TOT               x                                      x
# QREFHT                      x            x            x            x
# QRUNOFF                     x                                      x
# QVEGT                       x                                      x
# RH2M                        x                                      x
# RH2M_U                      x                                      x
# RHREFHT                     x            x            x            x
# SHFLX                       x                         x            x
# SOILWATER_10CM              x                                      x
# SST                         x            x            x            x
# TLAI                        x            x            x            x
# TOTFIRE                                  x            x
# TOTLITC                                  x            x
# TOTSOILLIQ                  x                                      x
# TOTVEGC                                  x            x
# TREFHT                      x            x            x            x
# TREFHTMN                    x            x            x            x
# TREFHTMX                    x            x            x            x
# TSOI_10CM                   x                                      x
# TWS                                      x            x
# U10                         x                                      x
# U200                        x                         x            x
# U500                        x                         x            x
# V200                        x                         x            x
# V500                        x                         x            x
# Z200                        x                         x            x
# Z500                        x            x            x            x
#
#                piControl-x4 piControl-x5
# EFLX_GNET                 x            x
# EFLX_LH_TOT               x            x
# FAREA_BURNED              x            x
# FIRE
# FLDS                      x            x
# FLNS                      x            x
# FSDS                      x            x
# FSH                       x            x
# FSNO                      x            x
# FSNS                      x            x
# GPP                       x            x
# HR
# ICEFRAC                   x            x
# LHFLX                     x            x
# NBP                       x            x
# PBOT                      x            x
# PRECC                     x            x
# PRECL                     x            x
# PS                        x            x
# PSL                       x            x
# QFLX_EVAP_TOT             x            x
# QREFHT                    x            x
# QRUNOFF                   x            x
# QVEGT                     x            x
# RH2M                      x            x
# RH2M_U                    x            x
# RHREFHT                   x            x
# SHFLX                     x            x
# SOILWATER_10CM            x            x
# SST                       x            x
# TLAI                      x            x
# TOTFIRE
# TOTLITC
# TOTSOILLIQ                x            x
# TOTVEGC
# TREFHT                    x            x
# TREFHTMN                  x            x
# TREFHTMX                  x            x
# TSOI_10CM                 x            x
# TWS
# U10                       x            x
# U200                      x            x
# U500                      x            x
# V200                      x            x
# V500                      x            x
# Z200                      x            x
# Z500                      x            x

# %%
available.columns = [f"x{exp.experiment_identifier[1]}" for exp in experiments.values()]

# %%
print("|                | ssp375-2025                      | piControl                        |")
# Out:
# |                | ssp375-2025                      | piControl                        |

# %%
print(available.iloc[:,:5].to_markdown())
# Out:
# |                | x1   | x2   | x3   | x4   | x5   |
# |:---------------|:-----|:-----|:-----|:-----|:-----|
# | EFLX_GNET      |      |      | x    | x    | x    |
# | EFLX_LH_TOT    |      |      | x    | x    | x    |
# | FAREA_BURNED   |      |      | x    | x    | x    |
# | FIRE           | x    | x    |      |      |      |
# | FLDS           |      | x    | x    | x    | x    |
# | FLNS           |      | x    | x    | x    | x    |
# | FSDS           |      | x    | x    | x    | x    |
# | FSH            |      |      | x    | x    | x    |
# | FSNO           |      |      | x    | x    | x    |
# | FSNS           |      | x    | x    | x    | x    |
# | GPP            | x    | x    | x    | x    | x    |
# | HR             | x    | x    |      |      |      |
# | ICEFRAC        | x    | x    | x    | x    | x    |
# | LHFLX          |      | x    | x    | x    | x    |
# | NBP            | x    | x    | x    | x    | x    |
# | PBOT           |      |      | x    | x    | x    |
# | PRECC          | x    | x    | x    | x    | x    |
# | PRECL          | x    | x    | x    | x    | x    |
# | PS             | x    | x    | x    | x    | x    |
# | PSL            | x    | x    | x    | x    | x    |
# | QFLX_EVAP_TOT  |      |      | x    | x    | x    |
# | QREFHT         | x    | x    | x    | x    | x    |
# | QRUNOFF        |      |      | x    | x    | x    |
# | QVEGT          |      |      | x    | x    | x    |
# | RH2M           |      |      | x    | x    | x    |
# | RH2M_U         |      |      | x    | x    | x    |
# | RHREFHT        | x    | x    | x    | x    | x    |
# | SHFLX          |      | x    | x    | x    | x    |
# | SOILWATER_10CM |      |      | x    | x    | x    |
# | SST            | x    | x    | x    | x    | x    |
# | TLAI           | x    | x    | x    | x    | x    |
# | TOTFIRE        | x    | x    |      |      |      |
# | TOTLITC        | x    | x    |      |      |      |
# | TOTSOILLIQ     |      |      | x    | x    | x    |
# | TOTVEGC        | x    | x    |      |      |      |
# | TREFHT         | x    | x    | x    | x    | x    |
# | TREFHTMN       | x    | x    | x    | x    | x    |
# | TREFHTMX       | x    | x    | x    | x    | x    |
# | TSOI_10CM      |      |      | x    | x    | x    |
# | TWS            | x    | x    |      |      |      |
# | U10            |      |      | x    | x    | x    |
# | U200           |      | x    | x    | x    | x    |
# | U500           |      | x    | x    | x    | x    |
# | V200           |      | x    | x    | x    | x    |
# | V500           |      | x    | x    | x    | x    |
# | Z200           |      | x    | x    | x    | x    |
# | Z500           | x    | x    | x    | x    | x    |
